# %% [markdown]
# #**Covid-19 Automated Statistics - DIY:**
# ## *A guide to python, pulling raw data from the web, converting data to information, displaying information in the form of graphs, telegram bots, script automation and raspberry pi servers.*
# # ![Corona_7dayAvg.png](data:image/png;base64,...)
#
# ---
